# %% [markdown]
# **This notebook is an exercise in the [Intro to Programming](https://www.kaggle.com/learn/intro-to-programming) course. You can reference the tutorial at [this link](https://www.kaggle.com/code/alexisbcook/arithmetic-and-variables).**
#
# ---

# %% [markdown]
# This exercise will get you started with running your own code.
#
# ### **Setup the notebook**
#
# To begin, run the code in the next cell.
#
# - Begin by clicking inside the code cell.
# - Click on the triangle (in the shape of a "Play button") that appears on the left of the code cell.
# - If your code was run successfully, you will see the output below the cell.
#
# Instead of clicking on the triangle, you can also run code by pressing Shift + Enter on your keyboard. Try this now! Nothing bad will happen if you run the code more than once.

# %% [markdown]
# ### **Question 1**
#
# You will run some code from the tutorial, so you can see how it works for yourself. Run the next code cell without changes.

# %%
print("I am ready for the exercise!")
# Out:
# I am ready for the exercise!

# %% [markdown]
# **If you see `I am ready for the next exercise!` above, You have successfully printed a message, and you're ready to move on to the next question.**

# %% [markdown]
# ### **Question 2**
#
# Now, you will print a message of your choosing. To do this, change `print("Your message here")` to use a different message. For example, you might like to change it to something like:
#
# - `print("Good morning!")`
# - `print("I am learning how to code :D")`
#
# Or, you might like to see what happens if you write something like `print("3+4")`. Does it return 7, does it just think of `"3+4"` as just another message?
#
# Make sure that your message is enclosed in quotation marks (`""`), and the message itself does not use quotation marks. For example, this will throw an error: `print("She said "great job" and gave me a high-five!")` because the message contains quotation marks. If you decide to take the Python course after completing this course, you will learn more about how to avoid this error in [Lesson 6](https://www.kaggle.com/colinmorris/strings-and-dictionaries).

# %%
# TODO: Change the message
print("Good morning!")
print("I am learning how to code:D")
# Out:
# Good morning!
# I am learning how to code:D
