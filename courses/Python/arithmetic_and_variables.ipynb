# %% [markdown]
# Welcome to the **Intro to Programming** course! This course is for you if you have never written a single line of code, and you are interested in learning data science and machine learning. (*If you do have programming experience and are just new to the Python language, the [Python course](https://www.kaggle.com/learn/python) is a better fit to get started.*)
#
# In this course, you will learn how to use code to get a computer to perform certain tasks for you. **Python** is one of the most popular programming languages for data science, and it's the language you'll learn in this course. Once you complete this course, you'll be fully prepared to progress to the [Python course](https://www.kaggle.com/learn/python), followed by the [Intro to Machine Learning course](https://www.kaggle.com/learn/intro-to-machine-learning).
#
# In this tutorial, you'll see several examples of Python code. You'll get a chance to write your own code in the exercise. (*if you'd like to preview the exercise, feel free to [take a look now](https://www.kaggle.com/code/christianeabacani/exercise-arithmetic-and-variables/edit).*)

# %% [markdown]
# ### Printing

# %% [markdown]
# One of the simplest (and most important!) tasks you can ask a computer to do is to print a message.
#
# In Python, we ask a computer to print a message for us by writing `print()` and putting the message inside the parenthesis and enclosed in quotation marks `""`. Below, we ask the computer to print the message `Hello, Christiane!`.

# %%
print("Hello, Christiane!")
# Out:
# Hello, Christiane!

# %% [markdown]
# The code inside the box (known as a **code cell**), and the computer's response (called the **output** of the code) is shown below the box. As you can see, the computer printed the message we wanted.

# %% [markdown]
# ### Arithmetic

# %% [markdown]
# We can also print the value of some arithmetic operation (such as addition, subtraction, multiplication, and even division).
#
# For example, in the next code cell, the computer adds 2 to 1 and then prints the result, which is 3.'
#
# > **Note**: Unlike when we were simply printing text, we don't use any quotation marks.

# %%
print(2 + 1)
# Out:
# 3

# %% [markdown]
# We can also do subtraction in python. The next code subtracts 5 from 9 and prints the result, which is 4.

# %%
print(9 - 5)
# Out:
# 4

# %% [markdown]
# You can do a lot of calculations with python! See the table below for some examples.
#
# | Operation | Symbol | Example |
# | ----------|--------|---------|
# | Addition       |   +    | 1 + 2 = 3   |
# | Subtraction    |   -    | 5 - 4 = 1   |
# | Multiplication |   *    | 4 * 2 = 8   |
# | Division       |   /    | 6 / 2 = 3   |
# | Floor Division |   //   | 10 // 3 = 3 |
# | Exponent       |   **   | 3 ** 2 = 9  |

# %% [markdown]
# You can control the order of the operation in long calculations with parenthesis.

# %%
print(((1 + 3) * (9 - 2) / 2) ** 2)
# Out:
# 196.0

# %% [markdown]
# In general, Python follows the [PEMDAS rule](https://www.mathsisfun.com/operation-order-pemdas.html) when deciding the order of the operations.

# %% [markdown]
# ### Comments

# %% [markdown]
# We use **comments** to annotate what code is doing. They help other people to understand your code, and they can also be helpful if you haven't looked at your own code in a while. So far, the code we have written is very short, but annotations become more important when you have written a lot of code.
#
# For example, in the next code cell, we multiply 3 by 2. We also add a comment (`# Multiply 3 by 2`) above the code to describe what the code is doing.

# %%
# Multiply 3 by 3
print(3 * 2)
# Out:
# 6

# %% [markdown]
# To indicate to Python that a line is a comment (and not a Python code), you need to write the pound sign (`#`) as the very first character.
#
# Once Python sees the pound sign and recognizes that the line is a comment, it is completely ignored by the computer. This is important, because just like in English or Filipino (or any other language!), Python is a language with very strict rules that need to be followed. Python is stricter than a human listener, though, and will just error if it can't understand the code.
#
# We can see an example of this, in the code cell below. Python errors if we remove the pound sign, because the text in the comment is not a valid Python code, so it can't be interpreted properly.

# %%
Multiply 3 by 3
print(3 * 2)
# Out:
#   Cell In[12], line 1
#     Multiply 3 by 3
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Variables

# %% [markdown]
# So far, you have used to make a calculation and print the result, and the result isn't saved anywhere. However, you can imagine that you might want to save the result to work with it later. For this, you'll need to use **variables**.

# %% [markdown]
# ##### Creating variables

# %% [markdown]
# The next code cell creates a variable named `test_var` and assignts it value that we get when we add 5 to 4.
#
# We print the value that is assigned to the variable, which is 9.

# %%
# Create a variable with a name of 'test_var' and give it a value from 5 + 4
test_var = 5 + 4

# Print the value of the variable
print(test_var)
# Out:
# 9
