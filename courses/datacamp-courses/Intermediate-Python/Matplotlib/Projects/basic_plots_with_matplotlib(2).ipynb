# %% [markdown]
# ### **Lesson: Basic Plots with Matplotlib**
#
# **Objective:** Use functions from `pyplot` sub-package of `matplotlib` package to perform data visualization methods such as [**Line Chart**](https://www.cuemath.com/data/line-chart/) to represent the changes of data-points that are connected through line over a series of time and  [**Scatter Plot**](https://www.geeksforgeeks.org/maths/scatter-plot/) to visualize the correlation or relationship of two variables.

# %% [markdown]
# What I learned:
# - Import `pyplot` sub-package from the main package `matplotlib` to use different methods or functions to perform data visualization.
# - Use `plot()` function to perform **Line Chart** visualization to track the changes of different data points over a series of time.
# - Use `scatter()` function to perfoorm **Scatter Plot** visualization to display the correlation or relationship between two variables.
# - Use `xlabel()` and `ylabel()` to create header for the horizontal-axis and vertical-axis of the line chart and scatter plot.
# - Use `show()` function to display the plot we created.

# %% [markdown]
# #### **Setup environment**
#
# Setup the packages, sub-packages, and modules to use to perform Data Visualization.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("..\Datasets\global_natural_disasters_2000_2025.csv")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# D:\Temp\ipykernel_7824\578533320.py:4: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv("..\Datasets\global_natural_disasters_2000_2025.csv")

# %% [markdown]
# ### **Line Chart**
#
# Use line chart to visualize the changes of earthquake magnitude over a course of time using `plot()` function.

# %%
# Clean the variables before plotting
df["date"] = pd.to_datetime(df["date"])
df = df[df["date"].dt.year > 2019]

# Visualize the trend/changes using line-plot
plt.plot(
    df["date"],
    df["magnitude"]
)
plt.xlabel("Date")
plt.ylabel("Magnitude")
plt.show()

# %% [markdown]
# As you can see above, the chart visualize the changes of magnitude over the course of time. We can see the highest earthquake magnitude happen on the year `2025`.

# %%
CONTINENT_KEYWORDS = {

    "Africa": [
        # North Africa
        "algeria", "egypt", "libya", "mauritania", "morocco",
        "sudan", "tunisia", "western sahara",
        # West Africa
        "benin", "burkina faso", "cabo verde", "cape verde",
        "gambia", "ghana", "guinea", "guinea-bissau", "ivory coast",
        "cote d'ivoire", "liberia", "mali", "niger", "nigeria",
        "senegal", "sierra leone", "togo",
        # Central Africa
        "angola", "cameroon", "central african republic", "chad",
        "congo", "democratic republic of the congo", "dr congo",
        "equatorial guinea", "gabon", "sao tome",
        # East Africa
        "burundi", "comoros", "djibouti", "eritrea", "ethiopia",
        "kenya", "madagascar", "malawi", "mauritius", "mozambique",
        "rwanda", "seychelles", "somalia", "south sudan",
        "tanzania", "uganda", "zambia", "zimbabwe",
        # Southern Africa
        "botswana", "eswatini", "swaziland", "lesotho", "namibia",
        "south africa",
        # Generic terms
        "africa", "sahara", "sahel", "nile", "kilimanjaro",
    ],

    "Asia": [
        # East Asia
        "china", "japan", "mongolia", "north korea", "south korea",
        "taiwan", "hong kong", "macau",
        "ryukyu", "honshu", "kyushu", "shikoku", "hokkaido",
        "sichuan", "yunnan", "tibet", "xinjiang",
        # South Asia
        "afghanistan", "bangladesh", "bhutan", "india", "maldives",
        "nepal", "pakistan", "sri lanka",
        "andaman", "nicobar", "kashmir", "hindu kush",
        # Southeast Asia
        "brunei", "cambodia", "indonesia", "laos", "malaysia",
        "myanmar", "burma", "philippines", "singapore", "thailand",
        "timor-leste", "east timor", "vietnam",
        "sumatra", "java", "borneo", "celebes", "sulawesi",
        "mindanao", "luzon", "visayas", "banda", "flores",
        "moluccas", "maluku", "irian", "sumbawa",
        # Central Asia
        "kazakhstan", "kyrgyzstan", "tajikistan", "turkmenistan",
        "uzbekistan",
        # Western Asia / Middle East
        "armenia", "azerbaijan", "bahrain", "cyprus", "georgia",
        "iran", "iraq", "israel", "jordan", "kuwait", "lebanon",
        "oman", "palestine", "qatar", "saudi arabia", "syria",
        "turkey", "turkiye", "united arab emirates", "uae", "yemen",
        "persian gulf", "red sea", "zagros", "euphrates",
        # Asian Russia
        "siberia", "kamchatka", "kuril", "sakhalin", "yakutia",
        "baikal", "ural", "chukchi", "magadan", "irkutsk",
        "krasnoyarsk", "vladivostok", "khabarovsk",
        # Generic
        "asia", "himalaya", "himalayas", "gobi",
    ],

    "Europe": [
        # Western Europe
        "andorra", "austria", "belgium", "france", "germany",
        "ireland", "liechtenstein", "luxembourg", "monaco",
        "netherlands", "portugal", "spain", "switzerland",
        "united kingdom", "england", "scotland", "wales",
        # Northern Europe
        "denmark", "estonia", "finland", "iceland", "latvia",
        "lithuania", "norway", "sweden",
        "faroe", "svalbard", "jan mayen",
        # Southern Europe
        "albania", "bosnia", "croatia", "greece", "italy",
        "kosovo", "malta", "montenegro", "north macedonia",
        "san marino", "serbia", "slovenia", "vatican",
        "aegean", "adriatic", "ionian", "sicily", "sardinia",
        # Eastern Europe
        "belarus", "bulgaria", "czech", "czechia", "hungary",
        "moldova", "poland", "romania", "russia", "slovakia",
        "ukraine",
        # Atlantic islands (European territory)
        "azores", "canary islands", "canary", "madeira",
        # Generic
        "europe", "alps", "balkans", "scandinavia",
    ],

    "North America": [
        # Countries
        "canada", "mexico", "united states", "belize",
        "costa rica", "el salvador", "guatemala", "honduras",
        "nicaragua", "panama",
        # Caribbean
        "antigua", "bahamas", "barbados", "cuba", "dominica",
        "dominican republic", "grenada", "haiti", "jamaica",
        "saint kitts", "saint lucia", "saint vincent",
        "trinidad", "tobago", "puerto rico", "caribbean",
        "virgin islands", "cayman", "turks and caicos", "aruba",
        "curacao", "martinique", "guadeloupe",
        # US states & regions
        "alaska", "hawaii", "california", "nevada", "oregon",
        "washington", "idaho", "montana", "wyoming", "utah",
        "arizona", "colorado", "new mexico", "oklahoma", "texas",
        "kansas", "nebraska", "south dakota", "north dakota",
        "minnesota", "iowa", "missouri", "arkansas", "louisiana",
        "mississippi", "alabama", "tennessee", "kentucky",
        "indiana", "illinois", "michigan", "ohio", "wisconsin",
        "georgia", "florida", "south carolina", "north carolina",
        "virginia", "west virginia", "maryland", "delaware",
        "pennsylvania", "new york", "new jersey", "connecticut",
        "rhode island", "massachusetts", "vermont", "new hampshire",
        "maine",
        # Geographic terms
        "aleutian", "near islands", "kodiak", "yakutat",
        "yellowstone", "appalachian", "great lakes",
        "gulf of mexico", "baja",
    ],

    "South America": [
        "argentina", "bolivia", "brazil", "chile", "colombia",
        "ecuador", "guyana", "paraguay", "peru", "suriname",
        "uruguay", "venezuela", "french guiana",
        "falkland", "malvinas", "galapagos",
        "andes", "amazon", "patagonia", "tierra del fuego",
        "atacama", "boyuibe", "antofagasta",
    ],

    "Australia": [
        # Countries
        "australia", "fiji", "kiribati", "marshall islands",
        "micronesia", "nauru", "new zealand", "palau",
        "papua new guinea", "samoa", "solomon islands", "tonga",
        "tuvalu", "vanuatu",
        # Islands & territories
        "american samoa", "cook islands", "french polynesia",
        "guam", "hawaii", "new caledonia", "niue",
        "northern mariana", "tokelau", "wallis", "futuna",
        "pitcairn", "easter island",
        # Geographic subregions
        "melanesia", "micronesia", "polynesia",
        "kermadec", "loyalty islands", "bismarck",
        "new britain", "new ireland", "bougainville", "panguna",
        "neiafu", "nuku alofa", "apia", "honiara",
        "new guinea", "irian jaya",
    ],

    "Antarctica": [
        "antarctica", "antarctic", "south pole", "ross ice",
        "weddell", "drake passage", "south georgia",
        "south sandwich", "south shetland", "bouvet",
        "heard island", "mcdonald islands",
    ],

    "Oceanic/Ridges": [
        # Ocean ridges & rises
        "mid-indian ridge", "mid-atlantic ridge", "east pacific rise",
        "southeast indian ridge", "carlsberg ridge",
        "pacific-antarctic ridge", "southwest indian ridge",
        "gakkel ridge", "reykjanes ridge",
        # Ocean basins & directional open-ocean
        "indian ocean", "pacific ocean", "atlantic ocean",
        "arctic ocean", "southern ocean",
        "mid-ocean", "triple junction",
    ],
}

# %%
def map_locations(location: str) -> str:
    location = location.lower()

    for continent, countries in CONTINENT_KEYWORDS.items():
        if any(country in location for country in countries):
            return continent

    return "Unknown"

df["continent"] = df["location"].apply(map_locations)

plt.scatter(
    df["continent"],
    df["magnitude"]
)
plt.xlabel("Continent", fontsize=12, labelpad=20)
plt.ylabel("Earthquake Magnitude", fontsize=12, labelpad=20)
plt.show()
