# %% [markdown]
# ### **Chapter: Matplotlib**
# ### **Lesson #1: Basic plot with Matplotlib**
#
# ---
#
# #### Data Visualization
# - Very important in Data Analysis
#     - It is useful to explore our dataset, the better we understand our data, the better we'll able to extract insights.
