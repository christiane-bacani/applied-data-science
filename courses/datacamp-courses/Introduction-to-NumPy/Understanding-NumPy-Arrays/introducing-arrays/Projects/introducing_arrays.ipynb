# %%
import numpy as np
import pandas as pd

df = pd.read_csv("../Datasets/mental_health.csv")

# %% [markdown]
# Creating one-dimensional array

# %%
person_id = np.array(df["Person_ID"])
age = np.array(df["Age"])
gender = np.array(df["Gender"])
occupation = np.array(df["Occupation"])
daily_screen_time = np.array(df["Daily_Screen_Time"])
social_media_usage = np.array(df["Social_Media_Usage"])
night_usage = np.array(df["Night_Usage"])
sleep_hours = np.array(df["Sleep_Hours"])
stress_level = np.array(df["Stress_Level"])
work_study_hours = np.array(df["Work_Study_Hours"])
physical_activity = np.array(df["Physical_Activity"])
social_interaction_score = np.array(df["Social_Interaction_Score"])
caffeine_intake = np.array(df["Caffeine_Intake"])
smoking = np.array(df["Smoking"])
alcohol = np.array(df["Alcohol"])
depression = np.array(df["Depression"])
anxiety = np.array(df["Anxiety"])
burnout = np.array(df["Burnout"])
