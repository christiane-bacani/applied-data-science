# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../Datasets/Dengue_diseases.csv")

# %% [markdown]
# ##### **#1 What dtype does a mixed-number list produce?**
#
# Your notebook shows that `np.array()` is homogeneous — it forces everything to one dtype. The dengue dataset has an `age` column with integers and a `hemoglobin_g_dl` column with floats.
#
# Without running it first, predict: what dtype will `np.array([6, 13.0, 29, 11.5])` produce — and why? Then confirm by running it and printing `.dtype`. Next, explain what this means about what happens to the integers.

# %%
import numpy as np

# Predict first — what dtype will this be?
sample = np.array([6, 13.0, 29, 11.5])

print("dtype:", float)        # fill in the attribute
print("values:", sample)

# Why are the integers 6 and 29 stored differently now?
# Write your explanation as a comment below:
# 6 and 29 become float because based on the elements of the one dimensional array
# it's easier to typecast integer to float rather than float to integer because they
# will lose accuracy and they followed a certain datatype hierarchy when globally typcasting
# an element, for example if most values are integer and boolean, the boolean are converted to
# integer. Hierarchy (boolean < integer < float < complex)
# Out:
# dtype: <class 'float'>
# values: [ 6.  13.  29.  11.5]

# %% [markdown]
# ##### **#2 The homogenous trap with gender labels**
# The homogeneous trap with `gender` labels
# The dengue dataset has a `gender` column with values like `"Male"`, `"Female"`, `"Child"` and a `dengue_label` column with `0` and `1`.
#
# Create a Python list mixing those: `["Male", "Female", 1, 0, "Child"]`. Pass it to `np.array()`. Before running, predict: will the numbers stay as integers? What will happen? Run it, print the array and its dtype. Then explain why `arr[2]` is not the number `1` anymore.

# %%
python_list = ["Male", "Female", 1, 0, "Child"]
arr = np.array(python_list)

# Prediction:
# The numbers will be converted into string dtype because converting them to string is much
# easier rather than convering the string dtype into integer. They follow a datatype hierarchy
# when performing typecasting if the elements have different datatype, if the datatype is higher
# than the other datatype present on the array, they will follow that datatype by coercing to that.

print(arr)
print(arr.dtype)
# Out:
# ['Male' 'Female' '1' '0' 'Child']
# <U21
