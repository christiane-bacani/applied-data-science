# %% [markdown]
# ## **Mini Project #2: Filtering dataset using pandas.DataFrame.loc and pandas.DataFrame.iloc**

# %% [markdown]
# ---
#
# This mini-project I built will use [**pandas.DataFrame.loc**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) and [**pandas.DataFrame.iloc**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html) to perform filtering and other necessary data manipulation task using [**Pandas**](https://pandas.pydata.org/pandas-docs/stable/index.html) of [**Python**](https://www.python.org/) Programming Language. This is essential because I want to test my skill if I already know the concept enough and I want to test it with a real world dataset specifically [**Trending Youtube Video Statistics**](https://www.kaggle.com/datasets/datasnaek/youtube-new?select=USvideos.csv) from [**Kaggle**](https://www.kaggle.com/).

# %% [markdown]
# ### **1. Loading dataset**
#
# Load the dataset using **Pandas** library of **Python** and setup the environment to disable scientific notations and use `IPython` library to produce clean output of every code cell.

# %%
import pandas as pd
from IPython.display import display

# Disable scientific notations from Pandas library methods
pd.set_option("display.float_format", "{:.2f}".format)

USvideos = pd.read_csv("../datasets/USvideos.csv")

# %% [markdown]
# ### **2. Quick Overview**

# %% [markdown]
# Get the conscise summary of the dataset's structure and descriptive statistics of the dataset using `info()` and `describe()` method respectively.

# %%
print("Dataset overview:")
display(USvideos.info())
# Out:
# Dataset overview:
# <class 'pandas.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  str
#  1   trending_date           40949 non-null  str
#  2   title                   40949 non-null  str
#  3   channel_title           40949 non-null  str
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  str
#  6   tags                    40949 non-null  str
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  str
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
#  14  video_error_or_removed  40949 non-null  bool
#  15  description             40379 non-null  str
# dtypes: bool(3), int64(5), str(8)
# memory usage: 4.2 MB
# None

# %%
display(USvideos[["views", "likes", "dislikes", "comment_count"]].describe())
# Out:
#              views      likes   dislikes  comment_count
# count     40949.00   40949.00   40949.00       40949.00
# mean    2360784.64   74266.70    3711.40        8446.80
# std     7394113.76  228885.34   29029.71       37430.49
# min         549.00       0.00       0.00           0.00
# 25%      242329.00    5424.00     202.00         614.00
# 50%      681861.00   18091.00     631.00        1856.00
# 75%     1823157.00   55417.00    1938.00        5755.00
# max   225211923.00 5613827.00 1674420.00     1361580.00

# %% [markdown]
# Get the dataset shape using `shape` attribute.

# %%
display(f"The number of rows and columns: {USvideos.shape}")
# Out:
# 'The number of rows and columns: (40949, 16)'

# %% [markdown]
# Check what columns or variables consist of **missing values** using `isnull()` and combine by `sum()` method to get the total number of values.

# %%
columns = USvideos.columns

for column in columns:
    no_of_missing_values = USvideos[column].isnull().sum()

    if no_of_missing_values > 0:
        display(f"Column: `{column}`")
        display(f"Number of missing values: {no_of_missing_values}")
# Out:
# 'Column: `description`'
# 'Number of missing values: 570'

# %% [markdown]
# Check the number of unique values for all columns with non-numeric values.

# %%
columns = [
    "video_id",
    "trending_date",
    "title",
    "channel_title",
    "publish_time",
    "tags",
    "description"
]

for column in columns:
    no_of_unique_values = len(USvideos[column].dropna().unique())
    display(f"Number of unique values of the column `{column}`: {no_of_unique_values}")
# Out:
# 'Number of unique values of the column `video_id`: 6351'
# 'Number of unique values of the column `trending_date`: 205'
# 'Number of unique values of the column `title`: 6455'
# 'Number of unique values of the column `channel_title`: 2207'
# 'Number of unique values of the column `publish_time`: 6269'
# 'Number of unique values of the column `tags`: 6055'
# 'Number of unique values of the column `description`: 6901'

# %% [markdown]
# Check the unique values of some columns.

# %%
for column in columns:
    unique_values = USvideos[column].dropna().unique()

    if column == "tags":
        unique_values = unique_values[:3]

    else:
        unique_values = unique_values[:5]
    
    display(f"Some unique values of column `{column}`:")
    display(unique_values)
# Out:
# 'Some unique values of column `video_id`:'
# <StringArray>
# ['2kyS6SvSYSE', '1ZAPwfrtAFY', '5qpjK5DgCt4', 'puqaWrEC7tY', 'd380meD0W0M']
# Length: 5, dtype: str
# 'Some unique values of column `trending_date`:'
# <StringArray>
# ['17.14.11', '17.15.11', '17.16.11', '17.17.11', '17.18.11']
# Length: 5, dtype: str
# 'Some unique values of column `title`:'
# <StringArray>
# [                            'WE WANT TO TALK ABOUT OUR MARRIAGE',
#  'The Trump Presidency: Last Week Tonight with John Oliver (HBO)',
#           'Racist Superman | Rudy Mancuso, King Bach & Lele Pons',
#                                'Nickelback Lyrics: Real or Fake?',
#                                        'I Dare You: GOING BALD!?']
# Length: 5, dtype: str
# 'Some unique values of column `channel_title`:'
# <StringArray>
# [         'CaseyNeistat',       'LastWeekTonight',          'Rudy Mancuso',
#  'Good Mythical Morning',              'nigahiga']
# Length: 5, dtype: str
# 'Some unique values of column `publish_time`:'
# <StringArray>
# ['2017-11-13T17:13:01.000Z', '2017-11-13T07:30:00.000Z',
#  '2017-11-12T19:05:24.000Z', '2017-11-13T11:00:04.000Z',
#  '2017-11-12T18:01:41.000Z']
# Length: 5, dtype: str
# 'Some unique values of column `tags`:'
# <StringArray>
# [                                                                                                                                                                                                                                                                                                           'SHANtell martin',
#                                                                                                                                                                                                                      'last week tonight trump presidency|"last week tonight donald trump"|"john oliver trump"|"donald trump"',
#  'racist superman|"rudy"|"mancuso"|"king"|"bach"|"racist"|"superman"|"love"|"rudy mancuso poo bear black white official music video"|"iphone x by pineapple"|"lelepons"|"hannahstocking"|"rudymancuso"|"inanna"|"anwar"|"sarkis"|"shots"|"shotsstudios"|"alesso"|"anitta"|"brazil"|"Getting My Driver's License | Lele Pons"']
# Length: 3, dtype: str
# 'Some unique values of column `description`:'
# <StringArray>
# ['SHANTELL'S CHANNEL - https://www.youtube.com/shantellmartin\nCANDICE - https://www.lovebilly.com\n\nfilmed this video in 4k on this -- http://amzn.to/2sTDnRZ\nwith this lens -- http://amzn.to/2rUJOmD\nbig drone - http://tinyurl.com/h4ft3oy\nOTHER GEAR ---  http://amzn.to/2o3GLX5\nSony CAMERA http://amzn.to/2nOBmnv\nOLD CAMERA; http://amzn.to/2o2cQBT\nMAIN LENS; http://amzn.to/2od5gBJ\nBIG SONY CAMERA; http://amzn.to/2nrdJRO\nBIG Canon CAMERA; http://tinyurl.com/jn4q4vz\nBENDY TRIPOD THING; http://tinyurl.com/gw3ylz2\nYOU NEED THIS FOR THE BENDY TRIPOD; http://tinyurl.com/j8mzzua\nWIDE LENS; http://tinyurl.com/jkfcm8t\nMORE EXPENSIVE WIDE LENS; http://tinyurl.com/zrdgtou\nSMALL CAMERA; http://tinyurl.com/hrrzhor\nMICROPHONE; http://tinyurl.com/zefm4jy\nOTHER MICROPHONE; http://tinyurl.com/jxgpj86\nOLD DRONE (cheaper but still great);http://tinyurl.com/zcfmnmd\n\nfollow me; on http://instagram.com/caseyneistat\non https://www.facebook.com/cneistat\non https://twitter.com/CaseyNeistat\n\namazing intro song by https://soundcloud.com/discoteeth\n\nad disclosure.  THIS IS NOT AN AD.  not selling or promoting anything.  but samsung did produce the Shantell Video as a 'GALAXY PROJECT' which is an initiative that enables creators like Shantell and me to make projects we might otherwise not have the opportunity to make.  hope that's clear.  if not ask in the comments and i'll answer any specifics.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'One year after the presidential election, John Oliver discusses what we've learned so far and enlists our catheter cowboy to teach Donald Trump what he hasn't.\n\nConnect with Last Week Tonight online...\n\nSubscribe to the Last Week Tonight YouTube channel for more almost news as it almost happens: www.youtube.com/user/LastWeekTonight\n\nFind Last Week Tonight on Facebook like your mom would: http://Facebook.com/LastWeekTonight\n\nFollow us on Twitter for news about jokes and jokes about news: http://Twitter.com/LastWeekTonight\n\nVisit our official site for all that other stuff at once: http://www.hbo.com/lastweektonight',
#                                                                                                                                                                                                                                           'WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► https://www.youtube.com/channel/UC5jkXpfnBhlDjqh0ir5FsIQ?sub_confirmation=1\n\nTHANKS FOR WATCHING! LIKE & SUBSCRIBE FOR MORE VIDEOS!\n-----------------------------------------------------------\nFIND ME ON: \nInstagram | http://instagram.com/rudymancuso\nTwitter | http://twitter.com/rudymancuso\nFacebook | http://facebook.com/rudymancuso\n\nCAST: \nRudy Mancuso | http://youtube.com/c/rudymancuso\nLele Pons | http://youtube.com/c/lelepons\nKing Bach | https://youtube.com/user/BachelorsPadTv\n\nVideo Effects: \nCaleb Natale | https://instagram.com/calebnatale\n\nPA:\nPaulina Gregory\n\n\nShots Studios Channels:\nAlesso | https://youtube.com/c/alesso\nAnitta | http://youtube.com/c/anitta\nAnwar Jibawi | http://youtube.com/c/anwar\nAwkward Puppets | http://youtube.com/c/awkwardpuppets\nHannah Stocking | http://youtube.com/c/hannahstocking\nInanna Sarkis | http://youtube.com/c/inanna\nLele Pons | http://youtube.com/c/lelepons\nMaejor | http://youtube.com/c/maejor\nMike Tyson | http://youtube.com/c/miketyson \nRudy Mancuso | http://youtube.com/c/rudymancuso\nShots Studios | http://youtube.com/c/shots\n\n#Rudy\n#RudyMancuso',
#         'Today we find out if Link is a Nickelback amateur or a secret Nickelback devotee. GMM #1218\nDon't miss an all new Ear Biscuits: https://goo.gl/xeZNQt\nWatch Part 4: https://youtu.be/MhCdiiB8CQg | Watch Part 2: https://youtu.be/7qiOrNao9fg\nWatch today's episode from the start: http://bit.ly/GMM1218\n\nPick up all of the official GMM merch only at https://mythical.store\n\nFollow Rhett & Link: \nInstagram: https://instagram.com/rhettandlink\nFacebook: https://facebook.com/rhettandlink\nTwitter: https://twitter.com/rhettandlink\nTumblr: https://rhettandlink.tumblr.com\nSnapchat: @realrhettlink\nWebsite: https://mythical.co/\n\nCheck Out Our Other Mythical Channels:\nGood Mythical MORE: https://youtube.com/goodmythicalmore\nRhett & Link: https://youtube.com/rhettandlink\nThis Is Mythical: https://youtube.com/thisismythical\nEar Biscuits: https://applepodcasts.com/earbiscuits\n\nWant to send us something? https://mythical.co/contact\nHave you made a Wheel of Mythicality intro video? Submit it here: https://bit.ly/GMMWheelIntro\n\nIntro Animation by Digital Twigs: https://www.digitaltwigs.com\nIntro & Outro Music by Jeff Zeigler & Sarah Schimeneck https://www.jeffzeigler.com\nWheel of Mythicality theme: https://www.royaltyfreemusiclibrary.com/\nAll Supplemental Music fromOpus 1 Music: https://opus1.sourceaudio.com/\nWe use ‘The Mouse’ by Blue Microphones https://www.bluemic.com/mouse/',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        'I know it's been a while since we did this show, but we're back with what might be the best episode yet!\nLeave your dares in the comment section! \n\nOrder my book how to write good \nhttp://higatv.com/ryan-higas-how-to-write-good-pre-order-links/\n\nJust Launched New Official Store\nhttps://www.gianthugs.com/collections/ryan\n\nHigaTV Channel\nhttp://www.youtube.com/higatv\n\nTwitter\nhttp://www.twitter.com/therealryanhiga\n\nFacebook\nhttp://www.facebook.com/higatv\n\nWebsite\nhttp://www.higatv.com\n\nInstagram\nhttp://www.instagram.com/notryanhiga\n\nSend us mail or whatever you want here!\nPO Box 232355\nLas Vegas, NV 89105']
# Length: 5, dtype: str

# %% [markdown]
# Check the number of unique values for some columns.

# %% [markdown]
# ### **3. Data Cleaning**

# %% [markdown]
# Now that we have the overview of what's inside the dataset such as the number of rows and columns, the number of missing values for all columns, unique values per column, and statistical description of the dataset. We will now proceed to clean the dataset based on what we've observed earlier on.

# %%
# Handle the missing values of the `description` column
USvideos["description"] = USvideos["description"].fillna("No description")

# Standardize the datatype of `trending_date` and `publish_time` columns
USvideos["trending_date"] = pd.to_datetime(USvideos["trending_date"], format="%y.%d.%m")
USvideos["publish_time"] = pd.to_datetime(USvideos["publish_time"], format="%Y-%m-%dT%H:%M:%S.%fZ")

# Remove unnecessary characters to the `tags` column
USvideos["tags"] = USvideos["tags"].str.replace("[none]", "No tags")
USvideos["tags"] = USvideos["tags"].str.replace("\"", "")
USvideos["tags"] = str(USvideos["tags"].str.split("|").str.join(", "))

# Remove duplicates of `video_id` column which is the unique identifier of the dataset
USvideos.drop_duplicates(subset=["video_id"], keep="last", inplace=True)

# %% [markdown]
# ### **4. Data Analysis**

# %% [markdown]
# After performing **data cleaning**, we can now proceed to analyze and gain insights by performing data filtering using [**pandas.DataFrame.loc**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) and [**pandas.DataFrame.iloc**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html) to the dataset.

# %% [markdown]
# Get the row with the index label of `40944` from the dataset.

# %%
display(USvideos.loc[40944])
# Out:
# video_id                                                        BZt0qjTWNhw
# trending_date                                           2018-06-14 00:00:00
# title                                          The Cat Who Caught the Laser
# channel_title                                                 AaronsAnimals
# category_id                                                              15
# publish_time                                            2018-05-18 13:00:04
# tags                      0                                          SHA...
# views                                                               1685609
# likes                                                                 38160
# dislikes                                                               1385
# comment_count                                                          2657
# thumbnail_link               https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg
# comments_disabled                                                     False
# ratings_disabled                                                      False
# video_error_or_removed                                                False
# description                  The Cat Who Caught the Laser - Aaron's Animals
# Name: 40944, dtype: object

# %% [markdown]
# Get all rows starting from the index label `10` to `75` using index label slicing.

# %%
display(USvideos.loc[10:76])
# Out:
#        video_id trending_date  \
# 10  9wRQljFNDW8    2017-11-14
# 36  Om_zGhJLZ5U    2017-11-14
# 41  goP4Z5wyOlM    2017-11-14
# 55  8NHA23f7LvU    2017-11-14
# 76  IE-xepGLVt8    2017-11-14
#
#                                                 title           channel_title  \
# 10  Dion Lewis' 103-Yd Kick Return TD vs. Denver! ...                     NFL
# 36     TL;DW - Every DCEU Movie Before Justice League          Screen Junkies
# 41  Iraq-Iran earthquake: Deadly tremor hits borde...                BBC News
# 55  Jason Momoa Wows Hugh Grant With Some Dothraki...  The Graham Norton Show
# 76  Mayo Clinic's first face transplant patient me...             Mayo Clinic
#
#     category_id        publish_time  \
# 10           17 2017-11-13 02:05:26
# 36            1 2017-11-12 18:00:03
# 41           25 2017-11-12 21:16:40
# 55           24 2017-11-10 19:06:23
# 76           28 2017-11-10 12:04:17
#
#                                                  tags    views  likes  \
# 10  0                                          SHA...    81377    655
# 36  0                                          SHA...   288922   7515
# 41  0                                          SHA...    34785    308
# 55  0                                          SHA...  1496225  16116
# 76  0                                          SHA...   237307   1896
#
#     dislikes  comment_count                                  thumbnail_link  \
# 10        25            177  https://i.ytimg.com/vi/9wRQljFNDW8/default.jpg
# 36       792           2111  https://i.ytimg.com/vi/Om_zGhJLZ5U/default.jpg
# 41        26            413  https://i.ytimg.com/vi/goP4Z5wyOlM/default.jpg
# 55       236            605  https://i.ytimg.com/vi/8NHA23f7LvU/default.jpg
# 76        74            260  https://i.ytimg.com/vi/IE-xepGLVt8/default.jpg
#
#     comments_disabled  ratings_disabled  video_error_or_removed  \
# 10              False             False                   False
# 36              False             False                   False
# 41              False             False                   False
# 55              False             False                   False
# 76              False             False                   False
#
#                                           description
# 10  New England Patriots returner Dion Lewis blast...
# 36  With Justice League approaching fast we rewatc...
# 41  A strong 7.2-magnitude earthquake has rattled ...
# 55  I think Sarah Millican was very excited for th...
# 76  One and a half years after the surgery that tr...

# %% [markdown]
# Get all the rows with an index label of `40944`, `40945`, `40946`, and `40947`.

# %%
display(USvideos.loc[[40944, 40945, 40946, 40947]])
# Out:
#           video_id trending_date  \
# 40944  BZt0qjTWNhw    2018-06-14
# 40945  1h7KV2sjUWY    2018-06-14
# 40946  D6Oy4LfoqsU    2018-06-14
# 40947  oV0zkMe1K8s    2018-06-14
#
#                                                    title  \
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
#
#                   channel_title  category_id        publish_time  \
# 40944             AaronsAnimals           15 2018-05-18 13:00:04
# 40945                  zefrank1           22 2018-05-18 01:00:06
# 40946                Brad Mondo           24 2018-05-18 17:34:22
# 40947  How It Should Have Ended            1 2018-05-17 17:00:04
#
#                                                     tags    views   likes  \
# 40944  0                                          SHA...  1685609   38160
# 40945  0                                          SHA...  1064798   60008
# 40946  0                                          SHA...  1066451   48068
# 40947  0                                          SHA...  5660813  192957
#
#        dislikes  comment_count  \
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
#
#                                        thumbnail_link  comments_disabled  \
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
#
#                                              description
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                     No description
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...

# %% [markdown]
# Get all the rows with `views` greater than or equal to **1,000,000** views using boolean masking.

# %%
high_viewed_USvideos = USvideos.loc[USvideos["views"] >= 1000000]
display(high_viewed_USvideos)
# Out:
#           video_id trending_date  \
# 55     8NHA23f7LvU    2017-11-14
# 78     cOc3tsFWoRs    2017-11-14
# 104    pz95u3UVpaM    2017-11-14
# 117    dW4wpGg64pE    2017-11-14
# 122    k29YnfttqEU    2017-11-14
# ...            ...           ...
# 40944  BZt0qjTWNhw    2018-06-14
# 40945  1h7KV2sjUWY    2018-06-14
# 40946  D6Oy4LfoqsU    2018-06-14
# 40947  oV0zkMe1K8s    2018-06-14
# 40948  ooyjaVdt-jA    2018-06-14
#
#                                                    title  \
# 55     Jason Momoa Wows Hugh Grant With Some Dothraki...
# 78         Jason Momoa & Lisa Bonet: Love at First Sight
# 104    Camila Cabello - Havana (Vertical Video) ft. Y...
# 117             Meryl Streep Meets Anna Wintour at Vogue
# 122               Mean Tweets – Country Music Edition #3
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                               channel_title  category_id        publish_time  \
# 55                   The Graham Norton Show           24 2017-11-10 19:06:23
# 78     The Late Late Show with James Corden           24 2017-11-10 09:35:00
# 104                       CamilaCabelloVEVO           10 2017-11-10 05:01:00
# 117                                   Vogue           24 2017-11-09 18:20:27
# 122                       Jimmy Kimmel Live           23 2017-11-09 04:58:04
# ...                                     ...          ...                 ...
# 40944                         AaronsAnimals           15 2018-05-18 13:00:04
# 40945                              zefrank1           22 2018-05-18 01:00:06
# 40946                            Brad Mondo           24 2018-05-18 17:34:22
# 40947              How It Should Have Ended            1 2018-05-17 17:00:04
# 40948                          Call of Duty           20 2018-05-17 17:09:38
#
#                                                     tags     views   likes  \
# 55     0                                          SHA...   1496225   16116
# 78     0                                          SHA...   1497519   15504
# 104    0                                          SHA...   5476737  286268
# 117    0                                          SHA...   1017803   25122
# 122    0                                          SHA...   1315873    9312
# ...                                                  ...       ...     ...
# 40944  0                                          SHA...   1685609   38160
# 40945  0                                          SHA...   1064798   60008
# 40946  0                                          SHA...   1066451   48068
# 40947  0                                          SHA...   5660813  192957
# 40948  0                                          SHA...  10306119  357079
#
#        dislikes  comment_count  \
# 55          236            605
# 78          353           1084
# 104        4083          12254
# 117         628           1504
# 122         584            769
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 55     https://i.ytimg.com/vi/8NHA23f7LvU/default.jpg              False
# 78     https://i.ytimg.com/vi/cOc3tsFWoRs/default.jpg              False
# 104    https://i.ytimg.com/vi/pz95u3UVpaM/default.jpg              False
# 117    https://i.ytimg.com/vi/dW4wpGg64pE/default.jpg              False
# 122    https://i.ytimg.com/vi/k29YnfttqEU/default.jpg              False
# ...                                               ...                ...
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 55                False                   False
# 78                False                   False
# 104               False                   False
# 117               False                   False
# 122               False                   False
# ...                 ...                     ...
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description
# 55     I think Sarah Millican was very excited for th...
# 78     James congratulates Jason Momoa on recently ma...
# 104    Havana – Spotify Vertical Video \nVideo Direct...
# 117    The pair had a frank and far-ranging conversat...
# 122    From time to time, we like to shine a light on...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                     No description
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [2176 rows x 16 columns]

# %% [markdown]
# Get the **top 10 most viewed US YouTube Videos**.

# %%
# Sort the row based on highest to lowest views
highest_viewed_USvideos = high_viewed_USvideos.sort_values(by="views", ascending=False)
top_10_highest_viewed_USvideos = highest_viewed_USvideos[:10]

top_10_highest_viewed_USvideos.to_csv("../outputs/top_10_highest_viewed_USvideos.csv", index=False)
display(top_10_highest_viewed_USvideos)
# Out:
#           video_id trending_date  \
# 38547  VYOjWnS4cMY    2018-06-02
# 6181   FlsCjmMhFmw    2017-12-14
# 34708  ffxKSjUwKdU    2018-05-14
# 34888  zEf423kYfqk    2018-05-15
# 38273  7C2z4GqqS5E    2018-06-01
# 34747  M4ZoCHID9GI    2018-05-14
# 2587   TyHvyGVs42U    2017-11-26
# 40869  xTlNMmZKwpA    2018-06-14
# 4997   6ZfuNTqbHE8    2017-12-08
# 25947  -BQJo3vK8O8    2018-03-25
#
#                                                    title  \
# 38547  Childish Gambino - This Is America (Official V...
# 6181   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 34708               Ariana Grande - No Tears Left To Cry
# 34888  Becky G, Natti Natasha - Sin Pijama (Official ...
# 38273                BTS (방탄소년단) 'FAKE LOVE' Official MV
# 34747     The Weeknd - Call Out My Name (Official Video)
# 2587           Luis Fonsi, Demi Lovato - Échame La Culpa
# 40869  Cardi B, Bad Bunny & J Balvin - I Like It [Off...
# 4997   Marvel Studios' Avengers: Infinity War Officia...
# 25947              Maluma - El Préstamo (Official Video)
#
#               channel_title  category_id        publish_time  \
# 38547   ChildishGambinoVEVO           10 2018-05-06 04:00:07
# 6181      YouTube Spotlight           24 2017-12-06 17:58:51
# 34708      ArianaGrandeVevo           10 2018-04-20 04:00:03
# 34888            BeckyGVEVO           10 2018-04-20 10:40:51
# 38273               ibighit           10 2018-05-18 09:00:02
# 34747         TheWeekndVEVO           10 2018-04-12 16:00:04
# 2587          LuisFonsiVEVO           10 2017-11-17 05:00:01
# 40869               Cardi B           10 2018-05-29 14:05:10
# 4997   Marvel Entertainment           24 2017-11-29 13:26:24
# 25947            MalumaVEVO           10 2018-03-09 11:00:01
#
#                                                     tags      views    likes  \
# 38547  0                                          SHA...  225211923  5023450
# 6181   0                                          SHA...  149376127  3093544
# 34708  0                                          SHA...  148689896  3094021
# 34888  0                                          SHA...  139334502  1425496
# 38273  0                                          SHA...  123010920  5613827
# 34747  0                                          SHA...  122544931  1427436
# 2587   0                                          SHA...  102012605  2376636
# 40869  0                                          SHA...   94254507  1816753
# 4997   0                                          SHA...   91933007  2625661
# 25947  0                                          SHA...   87264467   815369
#
#        dislikes  comment_count  \
# 38547    343541         517232
# 6181    1643059         810698
# 34708    129502         242039
# 34888    119798          83941
# 38273    206892        1228655
# 34747     40837          55320
# 2587     117196         134224
# 40869    102474         101077
# 4997      53709         350458
# 25947     71494          35945
#
#                                        thumbnail_link  comments_disabled  \
# 38547  https://i.ytimg.com/vi/VYOjWnS4cMY/default.jpg              False
# 6181   https://i.ytimg.com/vi/FlsCjmMhFmw/default.jpg              False
# 34708  https://i.ytimg.com/vi/ffxKSjUwKdU/default.jpg              False
# 34888  https://i.ytimg.com/vi/zEf423kYfqk/default.jpg              False
# 38273  https://i.ytimg.com/vi/7C2z4GqqS5E/default.jpg              False
# 34747  https://i.ytimg.com/vi/M4ZoCHID9GI/default.jpg              False
# 2587   https://i.ytimg.com/vi/TyHvyGVs42U/default.jpg              False
# 40869  https://i.ytimg.com/vi/xTlNMmZKwpA/default.jpg              False
# 4997   https://i.ytimg.com/vi/6ZfuNTqbHE8/default.jpg              False
# 25947  https://i.ytimg.com/vi/-BQJo3vK8O8/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 38547             False                   False
# 6181              False                   False
# 34708             False                   False
# 34888             False                   False
# 38273             False                   False
# 34747             False                   False
# 2587              False                   False
# 40869             False                   False
# 4997              False                   False
# 25947             False                   False
#
#                                              description
# 38547  “This is America” by Childish Gambino http://s...
# 6181   YouTube Rewind 2017. Celebrating the videos, p...
# 34708  No Tears Left To Cry (Official Video)Song Avai...
# 34888  Becky G & Natti Natasha – “Sin Pijama”NUEVO SE...
# 38273  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...
# 34747  Call Out My Name (Official Video)Taken from th...
# 2587   “Échame La Culpa” disponible ya en todas las p...
# 40869  Cardi B, Bad Bunny & J Balvin - I Like It from...
# 4997   There was an idea… Avengers: Infinity War. In ...
# 25947  Maluma - El Prestamo (Official Music Video)\nE...

# %% [markdown]
# Save the **top 10 most viewed US YouTube Videos** to a separated csv file.

# %%
top_10_highest_viewed_USvideos.to_csv("../outputs/top_10_highest_viewed_USvideos.csv", index=False)

# %% [markdown]
# Get the row with the index label of `2383` and extract only the value of the `title` column

# %%
display(USvideos.loc[2383, "title"])
# Out:
# "Chris Stapleton - Tryin' To Untangle My Mind (Audio)"

# %% [markdown]
# Get a group of rows starting from the index label `15500` to `15600` (inclusive) using index label slicing and extract only the values of the `description` column.

# %%
display(USvideos.loc[15500:15600, "description"])
# Out:
# 15514    Programme website: http://bbc.in/2FkwhuK Tom C...
# 15523    HAIM SISTER SISTER SISTER Tour on sale now: ht...
# 15525    For You (Fifty Shades Freed) (Official Video)\...
# 15527    $14,000 GOLD bar cut in half with a waterjet. ...
# 15528    The first eliminated queen packs up her drag s...
#                                ...
# 15589    The repeal of Net Neutrality is a hot topic in...
# 15590    David Schwimmer is stuck in an unhealthy relat...
# 15591    Please SUBSCRIBE - http://bit.ly/BWchannel\nTo...
# 15592    My Diamond Glow Powders http://bit.ly/2CJWrXw\...
# 15593    In her first TV interview since leaving the Wh...
# Name: description, Length: 67, dtype: str

# %% [markdown]
# Get all the rows with an index label of `23742`, `4772`, `33689` and extract only the values of `channel_title` column.

# %%
display(USvideos.loc[[23742, 4772, 33689], "channel_title"])
# Out:
# 23742    The Joint Forces Channel
# 4772                   Mark Rober
# 33689                   FORMULA 1
# Name: channel_title, dtype: str

# %% [markdown]
# Get all the rows of the dataset that the year from `publish_time` column starts from **2018** and up.

# %%
display(USvideos.loc[USvideos["publish_time"].dt.year >= 2018, "channel_title"])
# Out:
# 10006                               Netflix
# 10009                          TheEllenShow
# 10028                                   NFL
# 10029                            Refinery29
# 10206    The Late Show with Stephen Colbert
#                         ...
# 40944                         AaronsAnimals
# 40945                              zefrank1
# 40946                            Brad Mondo
# 40947              How It Should Have Ended
# 40948                          Call of Duty
# Name: channel_title, Length: 4128, dtype: str

# %% [markdown]
# Get the row with an index label of `5988` and extract the values from the specified columns: `channel_title`, `title`, `publish_time`, `views`, `likes`, `dislikes`, and `comment_count`.

# %%
display(USvideos.loc[5988, ["channel_title", "title", "publish_time", "views", "likes", "dislikes", "comment_count"]])
# Out:
# channel_title                              Just Marcus
# title            REACTING TO ME IN YOUTUBE REWIND 2017
# publish_time                       2017-12-08 13:04:18
# views                                            46706
# likes                                             3091
# dislikes                                            47
# comment_count                                      130
# Name: 5988, dtype: object
